# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

# 시각화 라이브러리 설정
# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

# RANDOM_SEED와 LABELS 설정
RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %%
df = pd.read_csv('zezu.csv', encoding='cp949')

# %%
df.shape    # 데이터 구성 확인
# Out:
# (151, 8)

# %%
df.isnull().values.any()    # 결측값 확인
# Out:
# False

# %%
df    # 데이터 출력
# Out:
#      시도      승인일자  이용건수_전체  이용금액_전체  이용건수_개인  이용금액_개인  이용건수_법인  이용금액_법인
# 0    제주  20230101    190.0   6227.0    179.0   5652.0     11.0    575.0
# 1    제주  20230102    231.0   8501.0    211.0   7151.0     20.0   1350.0
# 2    제주  20230103    231.0   8435.0    211.0   7049.0     21.0   1386.0
# 3    제주  20230104    234.0   8611.0    213.0   7190.0     21.0   1420.0
# 4    제주  20230105    230.0   8725.0    209.0   7330.0     21.0   1395.0
# ..   ..       ...      ...      ...      ...      ...      ...      ...
# 146  제주  20230527    232.0   7543.0    216.0   6698.0     16.0    846.0
# 147  제주  20230528    222.0   7047.0    208.0   6347.0     14.0    700.0
# 148  제주  20230529    226.0   7330.0    209.0   6447.0     16.0    883.0
# 149  제주  20230530    225.0   8396.0    204.0   6546.0     21.0   1850.0
# 150  제주  20230531    250.0   9914.0    225.0   7429.0     24.0   2485.0
#
# [151 rows x 8 columns]

# %%
mean = np.mean(df['이용금액_전체'])    # 평균

# %%
var = np.var(df['이용금액_전체'])    # 분산

# %%
std = np.std(df['이용금액_전체'])     # 표준편차

# %%
print(mean, var, std)
# Out:
# 8528.245033112582 1583170.3704223495 1258.2409826509188

# %%
q1 = df['이용금액_전체'].quantile(0.25)    # 이상치 구하기위한 공식
q2 = df['이용금액_전체'].quantile(0.5)
q3 = df['이용금액_전체'].quantile(0.75)
iqr = q3-q1

# %%
weird_data = df['이용금액_전체'] > q3 + 1.5*iqr
df[weird_data]    # 이상치로 걸린 데이터
# Out:
#      시도      승인일자  이용건수_전체  이용금액_전체  이용건수_개인  이용금액_개인  이용건수_법인  이용금액_법인
# 17   제주  20230118    234.0  10687.0    212.0   8633.0     22.0   2053.0
# 18   제주  20230119    245.0  11565.0    222.0   9458.0     22.0   2107.0
# 19   제주  20230120    271.0  13602.0    249.0  11290.0     22.0   2312.0
# 58   제주  20230228    247.0  10612.0    224.0   8452.0     23.0   2160.0
# 89   제주  20230331    259.0  10707.0    235.0   8388.0     24.0   2320.0
# 117  제주  20230428    256.0  10572.0    232.0   8049.0     24.0   2523.0

# %%
outlier_idx = df[weird_data].index    # 이상치의 인덱스번호 저장

# %%
for i in range(len(df)):
    if i in outlier_idx:
        df.loc[i, '이상'] = 1
    else:
        df.loc[i, '이상'] = 0

# %%
count_classes = pd.value_counts(df['이상'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Amount used")
plt.xticks(range(2), LABELS)
plt.xlabel("weird")
plt.ylabel("Frequency");

# %%
frauds = df[df.이상 == 1]
normal = df[df.이상 == 0]
frauds.shape
# Out:
# (6, 9)

# %%
normal.shape
# Out:
# (145, 9)

# %%
frauds.describe()
# Out:
#                승인일자     이용건수_전체       이용금액_전체     이용건수_개인       이용금액_개인  \
# count  6.000000e+00    6.000000      6.000000    6.000000      6.000000
# mean   2.023022e+07  252.000000  11290.833333  229.000000   9045.000000
# std    1.312692e+02   12.837445   1191.609905   12.712199   1196.298625
# min    2.023012e+07  234.000000  10572.000000  212.000000   8049.000000
# 25%    2.023012e+07  245.500000  10630.750000  222.500000   8404.000000
# 50%    2.023017e+07  251.500000  10697.000000  228.000000   8542.500000
# 75%    2.023031e+07  258.250000  11350.500000  234.250000   9251.750000
# max    2.023043e+07  271.000000  13602.000000  249.000000  11290.000000
#
#          이용건수_법인      이용금액_법인   이상
# count   6.000000     6.000000  6.0
# mean   22.833333  2245.833333  1.0
# std     0.983192   173.508982  0.0
# min    22.000000  2053.000000  1.0
# 25%    22.000000  2120.250000  1.0
# 50%    22.500000  2236.000000  1.0
# 75%    23.750000  2318.000000  1.0
# max    24.000000  2523.000000  1.0

# %%
normal.describe()
# Out:
#                승인일자     이용건수_전체       이용금액_전체     이용건수_개인      이용금액_개인  \
# count  1.450000e+02  145.000000    145.000000  145.000000   145.000000
# mean   2.023032e+07  228.186207   8413.931034  208.813793  7041.124138
# std    1.428070e+02   21.867653   1131.226213   18.704941   778.114217
# min    2.023010e+07  114.000000   3041.000000  108.000000  2793.000000
# 25%    2.023021e+07  223.000000   8179.000000  205.000000  6802.000000
# 50%    2.023032e+07  232.000000   8654.000000  211.000000  7219.000000
# 75%    2.023042e+07  241.000000   9112.000000  219.000000  7506.000000
# max    2.023053e+07  260.000000  10064.000000  237.000000  8177.000000
#
#           이용건수_법인      이용금액_법인     이상
# count  145.000000   145.000000  145.0
# mean    19.365517  1372.758621    0.0
# std      3.989246   458.193725    0.0
# min      6.000000   248.000000    0.0
# 25%     17.000000   936.000000    0.0
# 50%     21.000000  1554.000000    0.0
# 75%     22.000000  1675.000000    0.0
# max     24.000000  2485.000000    0.0

# %%
# Fraud 데이터와 Normal 데이터를 합치기
combined_data = pd.concat([frauds, normal])

# 그래프 생성
fig, ax = plt.subplots()

# Fraud 데이터를 빨간색으로 표시
ax.scatter(combined_data.이용건수_전체, combined_data.이용금액_전체, c=combined_data.index.map(lambda x: 'red' if x in frauds.index else 'blue'))

# 그래프 제목 설정
ax.set_title('Combined Fraud and Normal')

# x축, y축 레이블 설정
plt.xlabel('Number of uses')
plt.ylabel('Amount')

# 그래프 표시
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

#columns_to_keep = ['승인일자', '이용건수_전체', '이용금액_전체', '이상']
columns_to_keep = ['이용건수_전체', '이용금액_전체', '이상']
data = df[columns_to_keep]

data['이용건수_전체'] = StandardScaler().fit_transform(data['이용건수_전체'].values.reshape(-1, 1))
data['이용금액_전체'] = StandardScaler().fit_transform(data['이용건수_전체'].values.reshape(-1, 1))
# Out:
# C:\Users\ledu2\AppData\Local\Temp\ipykernel_20328\3180510416.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['이용건수_전체'] = StandardScaler().fit_transform(data['이용건수_전체'].values.reshape(-1, 1))
# C:\Users\ledu2\AppData\Local\Temp\ipykernel_20328\3180510416.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['이용금액_전체'] = StandardScaler().fit_transform(data['이용건수_전체'].values.reshape(-1, 1))

# %%
data
# Out:
#       이용건수_전체   이용금액_전체   이상
# 0   -1.780364 -1.780364  0.0
# 1    0.084966  0.084966  0.0
# 2    0.084966  0.084966  0.0
# 3    0.221453  0.221453  0.0
# 4    0.039470  0.039470  0.0
# ..        ...       ...  ...
# 146  0.130462  0.130462  0.0
# 147 -0.324497 -0.324497  0.0
# 148 -0.142513 -0.142513  0.0
# 149 -0.188009 -0.188009  0.0
# 150  0.949387  0.949387  0.0
#
# [151 rows x 3 columns]

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.이상 == 0]
X_train = X_train.drop(['이상'], axis=1)
print('-'*15)
print('X_train')
print(X_train)
print('-'*15)
print()

y_test = X_test['이상']
X_test = X_test.drop(['이상'], axis=1)
print()
print('-'*15)
print('X_test')
print(X_test)
print('-'*15)
print()

X_train = X_train.values
X_test = X_test.values
print()
print('-'*15)
print(X_train.shape, X_test.shape)
print('-'*15)
# Out:
# ---------------
# X_train
#       이용건수_전체   이용금액_전체
# 15  -0.006026 -0.006026
# 125  0.767404  0.767404
# 11  -0.051522 -0.051522
# 127  1.267858  1.267858
# 51   0.175957  0.175957
# ..        ...       ...
# 71   0.312445  0.312445
# 106  0.994883  0.994883
# 14  -1.825860 -1.825860
# 92   0.767404  0.767404
# 102  0.767404  0.767404
#
# [116 rows x 2 columns]
# ---------------
#
#
# ---------------
# X_test
#       이용건수_전체   이용금액_전체
# 76   0.630916  0.630916
# 18   0.721908  0.721908
# 82   0.084966  0.084966
# 81  -0.006026 -0.006026
# 143  0.585420  0.585420
# 31   0.084966  0.084966
# 78   0.494428  0.494428
# 64   0.357941  0.357941
# 55  -0.097018 -0.097018
# 85   0.676412  0.676412
# 45  -0.188009 -0.188009
# 12  -0.460984 -0.460984
# 36  -0.460984 -0.460984
# 9    0.130462  0.130462
# 19   1.904800  1.904800
# 137 -0.369993 -0.369993
# 114 -0.142513 -0.142513
# 146  0.130462  0.130462
# 56  -1.097926 -1.097926
# 133 -0.597472 -0.597472
# 29   0.266949  0.266949
# 84  -0.733960 -0.733960
# 26  -1.279910 -1.279910
# 132  0.448933  0.448933
# 124 -1.507389 -1.507389
# 142  0.812899  0.812899
# 111  0.494428  0.494428
# 67  -0.051522 -0.051522
# 98  -0.597472 -0.597472
# 30   0.266949  0.266949
# 22  -2.462802 -2.462802
# ---------------
#
#
# ---------------
# (116, 2) (31, 2)
# ---------------

# %%
X_train
# Out:
# array([[-0.00602594, -0.00602594],
#        [ 0.76740355,  0.76740355],
#        [-0.05152179, -0.05152179],
#        [ 1.26785792,  1.26785792],
#        [ 0.17595747,  0.17595747],
#        [ 0.31244502,  0.31244502],
#        [-1.96234758, -1.96234758],
#        [-0.87044713, -0.87044713],
#        [ 0.03946991,  0.03946991],
#        [ 0.03946991,  0.03946991],
#        [-2.14433099, -2.14433099],
#        [ 1.08587451,  1.08587451],
#        [-0.18800935, -0.18800935],
#        [-0.05152179, -0.05152179],
#        [ 0.35794088,  0.35794088],
#        [ 0.94938695,  0.94938695],
#        [-2.00784344, -2.00784344],
#        [-0.32449691, -0.32449691],
#        [ 0.13046162,  0.13046162],
#        [ 0.08496576,  0.08496576],
#        [ 0.85839525,  0.85839525],
#        [ 0.8128994 ,  0.8128994 ],
#        [-0.91594298, -0.91594298],
#        [-1.78036418, -1.78036418],
#        [ 0.31244502,  0.31244502],
#        [ 0.31244502,  0.31244502],
#        [-1.91685173, -1.91685173],
#        [ 0.35794088,  0.35794088],
#        [ 0.49442843,  0.49442843],
#        [ 0.40343673,  0.40343673],
#        [ 0.72190769,  0.72190769],
#        [ 0.03946991,  0.03946991],
#        [-1.37090151, -1.37090151],
#        [-0.18800935, -0.18800935],
#        [-5.05606553, -5.05606553],
#        [ 0.8128994 ,  0.8128994 ],
#        [-0.36999276, -0.36999276],
#        [-0.32449691, -0.32449691],
#        [ 0.31244502,  0.31244502],
#        [ 0.35794088,  0.35794088],
#        [ 1.22236207,  1.22236207],
#        [-0.82495128, -0.82495128],
#        [ 0.31244502,  0.31244502],
#        [ 0.31244502,  0.31244502],
#        [-0.64296787, -0.64296787],
#        [ 0.63091599,  0.63091599],
#        [ 0.22145332,  0.22145332],
#        [ 0.53992429,  0.53992429],
#        [ 0.03946991,  0.03946991],
#        [ 0.17595747,  0.17595747],
#        [ 0.22145332,  0.22145332],
#        [ 0.63091599,  0.63091599],
#        [ 1.22236207,  1.22236207],
#        [-1.41639736, -1.41639736],
#        [-1.37090151, -1.37090151],
#        [-0.00602594, -0.00602594],
#        [-0.96143884, -0.96143884],
#        [-0.05152179, -0.05152179],
#        [-1.46189321, -1.46189321],
#        [ 0.08496576,  0.08496576],
#        [-2.05333929, -2.05333929],
#        [ 0.67641184,  0.67641184],
#        [-0.96143884, -0.96143884],
#        [ 0.22145332,  0.22145332],
#        [ 0.94938695,  0.94938695],
#        [ 0.94938695,  0.94938695],
#        [ 0.08496576,  0.08496576],
#        [-0.1425135 , -0.1425135 ],
#        [-0.18800935, -0.18800935],
#        [ 0.76740355,  0.76740355],
#        [ 0.22145332,  0.22145332],
#        [ 0.22145332,  0.22145332],
#        [ 0.35794088,  0.35794088],
#        [ 0.8128994 ,  0.8128994 ],
#        [-0.36999276, -0.36999276],
#        [ 0.63091599,  0.63091599],
#        [ 0.49442843,  0.49442843],
#        [ 0.08496576,  0.08496576],
#        [-1.32540565, -1.32540565],
#        [ 0.72190769,  0.72190769],
#        [ 0.40343673,  0.40343673],
#        [ 0.31244502,  0.31244502],
#        [-0.09701765, -0.09701765],
#        [-0.05152179, -0.05152179],
#        [-0.18800935, -0.18800935],
#        [ 0.40343673,  0.40343673],
#        [-0.1425135 , -0.1425135 ],
#        [-0.00602594, -0.00602594],
#        [-1.05243054, -1.05243054],
#        [-0.46098446, -0.46098446],
#        [-0.00602594, -0.00602594],
#        [ 1.17686622,  1.17686622],
#        [-0.27900105, -0.27900105],
#        [ 0.58542014,  0.58542014],
#        [-5.23804894, -5.23804894],
#        [ 0.49442843,  0.49442843],
#        [ 1.40434548,  1.40434548],
#        [ 1.04037866,  1.04037866],
#        [ 0.08496576,  0.08496576],
#        [ 0.53992429,  0.53992429],
#        [ 0.08496576,  0.08496576],
#        [ 0.17595747,  0.17595747],
#        [ 0.94938695,  0.94938695],
#        [-0.05152179, -0.05152179],
#        [ 0.9038911 ,  0.9038911 ],
#        [ 0.72190769,  0.72190769],
#        [ 0.63091599,  0.63091599],
#        [ 0.17595747,  0.17595747],
#        [ 1.26785792,  1.26785792],
#        [ 0.94938695,  0.94938695],
#        [ 0.08496576,  0.08496576],
#        [ 0.31244502,  0.31244502],
#        [ 0.99488281,  0.99488281],
#        [-1.82586003, -1.82586003],
#        [ 0.76740355,  0.76740355],
#        [ 0.76740355,  0.76740355]])

# %%
input_dim = X_train.shape[1]
encoding_dim = 14

input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim, activation="tanh", 
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)
decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)
autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
nb_epoch = 50
batch_size = 32
autoencoder.compile(optimizer='adam', 
                    loss='mean_squared_error', 
                    metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/50
# 4/4 [==============================] - 1s 56ms/step - loss: 1.1682 - accuracy: 0.6983 - val_loss: 0.6779 - val_accuracy: 0.6774
# Epoch 2/50
# 4/4 [==============================] - 0s 22ms/step - loss: 1.1462 - accuracy: 0.8103 - val_loss: 0.6621 - val_accuracy: 0.8710
# Epoch 3/50
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1255 - accuracy: 0.8793 - val_loss: 0.6530 - val_accuracy: 0.9677
# Epoch 4/50
# 4/4 [==============================] - 0s 21ms/step - loss: 1.1131 - accuracy: 0.9483 - val_loss: 0.6483 - val_accuracy: 1.0000
# Epoch 5/50
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1071 - accuracy: 0.9828 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 6/50
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1007 - accuracy: 0.9828 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 7/50
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0973 - accuracy: 0.9828 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 8/50
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 9/50
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 10/50
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 11/50
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 12/50
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 13/50
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 14/50
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 15/50
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 16/50
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 17/50
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 18/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 19/50
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 20/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 21/50
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 22/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 23/50
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 24/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 25/50
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 26/50
# 4/4 [==============================] - 0s 18ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 27/50
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 28/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 29/50
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 30/50
# 4/4 [==============================] - 0s 18ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 31/50
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 32/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 33/50
# 4/4 [==============================] - 0s 18ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 34/50
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 35/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 36/50
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 37/50
# 4/4 [==============================] - 0s 21ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 38/50
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 39/50
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 40/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 41/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 42/50
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 43/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 44/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 45/50
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 46/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 47/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 48/50
# 4/4 [==============================] - 0s 21ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 49/50
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000
# Epoch 50/50
# 4/4 [==============================] - 0s 21ms/step - loss: 1.0940 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 1.0000

# %%
autoencoder = load_model('model.h5')

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import StandardScaler

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import StandardScaler

# 모델 로드
model = keras.models.load_model('model.h5')

# 거래량과 거래비용 입력 (예시)
transaction_volume = np.array([230.0])  # 거래량 값 (숫자로 변환)
transaction_cost = np.array([8200.0])   # 거래비용 값 (숫자로 변환)

# 스케일링을 위한 객체 생성
scaler = StandardScaler()

# 스케일링을 학습 데이터의 통계 정보로 적용
scaler.fit(data[['이용건수_전체', '이용금액_전체']])

# 테스트 데이터에 스케일링 적용
scaled_test_data = scaler.transform(np.column_stack((transaction_volume, transaction_cost)))

# 모델을 사용하여 예측 수행
reconstructed_data = model.predict(scaled_test_data)

# 입력 데이터와 복원된 데이터 간의 차이 계산
reconstruction_error = np.mean(np.square(scaled_test_data - reconstructed_data))

# 임계값 설정 (필요한 경우 조정)
threshold = 0.1  # 이상치로 판단할 임계값

# 이상치 여부 확인
if reconstruction_error > threshold:
    print("입력 데이터는 이상치입니다.")
else:
    print("입력 데이터는 정상입니다.")
# Out:
# 1/1 [==============================] - 0s 63ms/step
# 입력 데이터는 이상치입니다.
# C:\Users\ledu2\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
